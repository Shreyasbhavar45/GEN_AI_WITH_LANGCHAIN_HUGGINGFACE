# %% [markdown]
# # __Importing , Creating Modules and Packages__
# - In python modules and packages help oraganize and reuse the code here a comprehensive guide on how to import them.

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy #wherever you want to create array or work array..
import numpy as np #--alias

"""for installing or using numoy we using rquirement .txt"""

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import * #by using * we can able to access all the elements at that packages
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.math import addition
addition(2,3)

# or write
# Out:
# 5

# %%
from package import math
math.addition(2,3)
# Out:
# 5

# %% [markdown]
# - __U want to at that folder location whenever you called that or run that file__

# %% [markdown]
# - __In package make a file test.py__

# %%
from package.math import *
print(addition(3,4))
print(substraction(4,2))
# Out:
# 7
# 2
