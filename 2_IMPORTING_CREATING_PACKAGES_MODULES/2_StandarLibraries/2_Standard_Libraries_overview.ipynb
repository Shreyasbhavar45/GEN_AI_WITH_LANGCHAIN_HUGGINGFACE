# %% [markdown]
# #
# - __Python Standard libraries is the vast collection of modules and packages that come bundled with python , providing a wide range of functionalities out of the box , here an overview of some most common;y used modules__

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %% [markdown]
# ##
# - __random__

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cheeku']))
# Out:
# 7
# banana

# %% [markdown]
# #
# - __File And Directory Access__

# %%
import os
print(os.getcwd())
# Out:
# /Users/shreyas/IT/GEN_AI/GEN_AI_WITH_LANGCHAIN_HUGGINGFACE/2_IMPORTING_CREATING_PACKAGES_MODULES/2_StandarLibraries

# %%
os.mkdir('test_dir')

# %% [markdown]
# #
# - __Find the function that is use to create any file__

# %%
# Function used to create a file: open()
# 'w' mode creates the file if it does not exist.

with open('sample.txt', 'w') as file:
    file.write('This file is created using open()')

print('sample.txt file created successfully')
# Out:
# sample.txt file created successfully

# %% [markdown]
# - __High Level operations on files and collection of files__

# %%
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %% [markdown]
# ## __Data Serialization__
# - __Converting and dicitonary to JSON__
# - __Converting Data Frame in Json__

# %%
import json
data = {'name':'krish','age':25}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))
# Out:
# {"name": "krish", "age": 25}
# <class 'str'>

# %%
#converting json into dictionary
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {'name': 'krish', 'age': 25}
# <class 'dict'>

# %% [markdown]
# ## __CSV FILE__

# %%
import csv
with open('example.csv',mode = 'w',newline = '')as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['shreyas','30'])


with open('example.csv',mode = 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['shreyas', '30']

# %%
##date and time
from datetime import datetime,timedelta
now = datetime.now()
print(now)

yesterday = now - timedelta(days = 1)
print(yesterday)
# Out:
# 2026-08-29 22:08:17.276509
# 2026-08-28 22:08:17.276509

# %%
##Time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1788021541.5932648
# 1788021543.598604

# %% [markdown]
# ##
# - __Regular expression - on entire dataset__

# %%
import re
pattern = r'\d'
text = 'these are 123 apples'
match = re.search(pattern,text)
print(match.group())
# Out:
# 1
