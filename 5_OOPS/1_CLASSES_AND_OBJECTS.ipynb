# %% [markdown]
# ## __CLASSES AND OBJECTS__
#
# - object oriented programming is a programming paradigm that uses 'objects' to design applications and computer programs . OOP allows for modeling real words scenarios using classes and objects . This lesson covers the basic of creating and bojects including instance variable and methods

# %%
# L = Class
# L = [1,2,3] -> Object

L = [1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
# Object Literal
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
L = list()
L
# Out:
# []

# %%
s = str()
s
# Out:
# ''

# %%
##object + is an instance of class
# Syntax to create an Object
''' 
objectname = classname()

'''

# %% [markdown]
# ## __CREATING A ATM CLASS__

# %%
# Pascal Case
# Evey new word start with capital letter is called pascal

HelloWorld

# %%
# Creating A Atm Class

class Atm:

    # Constructor :- A function inside the class
    def __init__(self):
        self.pin = ' '
        self.balance = 0

# %%
# How To make Object

obj = Atm()

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
# Creating A Atm Class

class Atm:

    # Constructor :- A function inside the class
    # It is a special Function it have superpower
    # Superpower of constructor is automatically call we dont need to call consturctor
    def __init__(self):
        self.pin = ' '
        self.balance = 0
        self.menu()
    
    def menu(self):
        user_input = input("""
                           
        Hi How can I help You ?
        1.Press 1 to create pin
        2.Press 2 to change pin
        3.Press 3 to check balance
        4.Press 4 to with draw
        5.Anything else to exit
""")
        
        if user_input == '1':
            #Create pin
            self.create_pin()

        elif user_input == '2':
            #change pin
            self.change_pin()
        elif user_input == '3':
            #check Balance
            self.check_balance()
        elif user_input == '4':
            #withdraw
            self.withdraw()
        else:
            exit
 
    def create_pin(self):

        user_pin = input('Enter Your Pin')
        self.pin = user_pin

        user_balance = int(input("Enter The Balance"))
        self.balance = user_balance

        print('Pin Created Succesfully')
        self.menu()

    def change_pin(self):
        old_pin = input('Enter old pin')

        if old_pin == self.pin:
            #Let him change the pin
            new_pin = input('Enter new Pin')
            self.pin = new_pin
            print('pin change succesfully')
            self.menu()

        else:
            print('You cant change the pin')
            self.menu()

    def check_balance(self):

        user_pin = input('Enter Your Pin')
        if user_pin == self.pin:
            print('Your Balance is',self.balance)

        else:
            print('You Enter Wrong Pin')

    def withdraw(self):

        user_pin = input('Enter the pin')
        if user_pin == self.pin:
            #Allowed to withdraw
            amount = int(input('Enter The amount'))

            if amount <= self.balance:
                self.balance = self.balance - amount

                print('Withdrawl Succesful balance is',self.balance)
            else:
                print('You have Unsufficient Balance')
        
        else:
            print("You Entered wrong pin")

        self.menu()

# %%
obj = Atm()

# %% [markdown]
# ## __Methods And Functions__

# %%
L = [1,2,3]
# Len is a Function because it is outside the list class
len(L)
#L.append() is a method because it is inside the list class
L.append(4)

# %% [markdown]
# ## __CLASS DIAGRAM__

# %% [markdown]
# ![alt text](image.png)

# %% [markdown]
# ## __Magic Methods / Dunder Method__
#
# - __Magic methods are special methods . And every magic method have own superpower__
# - __def __init__ is also a magic method__

# %% [markdown]
# # __When To Use The Constructor__
#
# - A constructor is a special method inside a class that automatically runs when we create an object.

# %%
class Temp:
    
    def __init__(self):
        print("Hello")

obj = Temp()

##What Is True Benefit of Constructorr???
# ->
# Out:
# Hello
# ' -> '

# %% [markdown]
# ## __What Is Self?__
