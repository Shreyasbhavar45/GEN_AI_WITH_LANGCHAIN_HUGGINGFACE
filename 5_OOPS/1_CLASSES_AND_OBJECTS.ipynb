# %% [markdown]
# ## __CLASSES AND OBJECTS__
#
# - object oriented programming is a programming paradigm that uses 'objects' to design applications and computer programs . OOP allows for modeling real words scenarios using classes and objects . This lesson covers the basic of creating and bojects including instance variable and methods

# %%
# A class is a blue print for creating Objects . Attribute , Methods

class Car:
    pass

# Objects
audi = Car()
bmw = Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
# It is car Object at specific memory Location
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x107a7b8d0>
# <__main__.Car object at 0x107a7b890>

# %%
audi.windows = 4

print(audi.windows)
# Out:
# 4

# %%
### doors is attribute

tata = Car()
tata.doors = 4
print(tata.window)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       3 tata = Car()
#       4 tata.doors = 4
# ----> 5 print(tata.window)
#
# AttributeError: 'Car' object has no attribute 'window'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
### Instance Variable And Methods

class Dog:
